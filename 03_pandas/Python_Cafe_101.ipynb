# %%
# a Pandas Cookbook könyv alapján haladunk
# https://www.packtpub.com/big-data-and-business-intelligence/pandas-cookbook
import pandas as pd
movie = pd.read_csv('C:\Anaconda\data\movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
# color                        4897 non-null object
# director_name                4814 non-null object
# num_critic_for_reviews       4867 non-null float64
# duration                     4901 non-null float64
# director_facebook_likes      4814 non-null float64
# actor_3_facebook_likes       4893 non-null float64
# actor_2_name                 4903 non-null object
# actor_1_facebook_likes       4909 non-null float64
# gross                        4054 non-null float64
# genres                       4916 non-null object
# actor_1_name                 4909 non-null object
# movie_title                  4916 non-null object
# num_voted_users              4916 non-null int64
# cast_total_facebook_likes    4916 non-null int64
# actor_3_name                 4893 non-null object
# facenumber_in_poster         4903 non-null float64
# ...

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
print (movie.iloc[0]) # kiírja az elso sort
# Out:
# color                                                                    Color
# director_name                                                    James Cameron
# num_critic_for_reviews                                                     723
# duration                                                                   178
# director_facebook_likes                                                      0
# actor_3_facebook_likes                                                     855
# actor_2_name                                                  Joel David Moore
# actor_1_facebook_likes                                                    1000
# gross                                                              7.60506e+08
# genres                                         Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                       CCH Pounder
# movie_title                                                             Avatar
# ...

# %%
print( type(movie.loc[0]))   # minden egyes oszlop egy Pandas series
# Out:
# <class 'pandas.core.series.Series'>

# %%
# metaadat - adatról szóló adat. A df is sok ilyen körítést tartalmaz. pl df.info

# %%
movie = movie.set_index('movie_title')

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie.loc['Tangled']
# Out:
# color                                                                    Color
# director_name                                                     Nathan Greno
# num_critic_for_reviews                                                     324
# duration                                                                   100
# director_facebook_likes                                                     15
# actor_3_facebook_likes                                                     284
# actor_2_name                                                      Donna Murphy
# actor_1_facebook_likes                                                     799
# gross                                                              2.00807e+08
# genres                       Adventure|Animation|Comedy|Family|Fantasy|Musi...
# actor_1_name                                                      Brad Garrett
# num_voted_users                                                         294810
# ...

# %%
movie['director_name']
#Alternatively, you may use the dot notation to accomplish the same task:
movie.director_name
# Out:
# movie_title
# Avatar                                              James Cameron
# Pirates of the Caribbean: At World's End           Gore Verbinski
# Spectre                                                Sam Mendes
# The Dark Knight Rises                           Christopher Nolan
# Star Wars: Episode VII - The Force Awakens            Doug Walker
# John Carter                                        Andrew Stanton
# Spider-Man 3                                            Sam Raimi
# Tangled                                              Nathan Greno
# Avengers: Age of Ultron                               Joss Whedon
# Harry Potter and the Half-Blood Prince                David Yates
# Batman v Superman: Dawn of Justice                    Zack Snyder
# Superman Returns                                     Bryan Singer
# Quantum of Solace                                    Marc Forster
# Pirates of the Caribbean: Dead Man's Chest         Gore Verbinski
# ...

# %%
import pandas as pd
movie2 = pd.read_csv('C:\Anaconda\data\movie.csv')
movie2.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movie2 = movie.set_index('director_name')

# %%
movie2.loc['James Cameron']
# Out:
#                color  num_critic_for_reviews  duration  \
# director_name
# James Cameron  Color                   723.0     178.0
# James Cameron  Color                   315.0     194.0
# James Cameron  Color                   210.0     153.0
# James Cameron  Color                    94.0     141.0
# James Cameron  Color                    82.0     171.0
# James Cameron  Color                   250.0     154.0
# James Cameron  Color                   204.0     107.0
#
#                director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                      0.0                   855.0
# James Cameron                      0.0                   794.0
# James Cameron                      0.0                   539.0
# James Cameron                      0.0                   618.0
# James Cameron                      0.0                   638.0
# James Cameron                      0.0                   604.0
# ...

# %%
movie2.iloc[3:5,8:12]
# Out:
#                             genres actor_1_name  num_voted_users  \
# director_name
# Christopher Nolan  Action|Thriller    Tom Hardy          1144337
# Doug Walker            Documentary  Doug Walker                8
#
#                    cast_total_facebook_likes
# director_name
# Christopher Nolan                     106759
# Doug Walker                              143

# %%
'''Conversely, it is possible to turn the index into a column with the reset_index method.
This will make movie_title a column again and revert the index back to a RangeIndex.
reset_index always puts the column as the very first one in the DataFrame, so the
columns may not be in their original order:
 movie2.reset_index()
 '''
# Out:
# 'Conversely, it is possible to turn the index into a column with the reset_index method.\nThis will make movie_title a column again and revert the index back to a RangeIndex.\nreset_index always puts the column as the very first one in the DataFrame, so the\ncolumns may not be in their original order:\n movie2.reset_index()\n '

# %%
columns = movie2.columns
print (columns)
# Out:
# Index(['color', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
print(movie2[movie2['country'] == 'USA'])
# Out:
#                               color  num_critic_for_reviews  duration  \
# director_name
# James Cameron                 Color                   723.0     178.0
# Gore Verbinski                Color                   302.0     169.0
# Christopher Nolan             Color                   813.0     164.0
# Andrew Stanton                Color                   462.0     132.0
# Sam Raimi                     Color                   392.0     156.0
# Nathan Greno                  Color                   324.0     100.0
# Joss Whedon                   Color                   635.0     141.0
# Zack Snyder                   Color                   673.0     183.0
# Bryan Singer                  Color                   434.0     169.0
# Gore Verbinski                Color                   313.0     151.0
# Gore Verbinski                Color                   450.0     150.0
# Zack Snyder                   Color                   733.0     143.0
# ...

# %%
print(movie2[movie2['actor_1_facebook_likes'] >1000].head())
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Sam Raimi          Color                   392.0     156.0
# Joss Whedon        Color                   635.0     141.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
# Sam Raimi                              0.0                  4000.0
# Joss Whedon                            0.0                 19000.0
#
#                         actor_2_name  actor_1_facebook_likes        gross  \
# director_name
# Gore Verbinski         Orlando Bloom                 40000.0  309404152.0
# ...

# %%
#    Visszatértem a könyv szerinti példához, tehát az eredeti movie nevű df-hez.
#    A Pandas Cookbook Könyv 17. oldalától megyek
'''Én egy többsoros
          komment vagyok'''
index = movie.index              
columns = movie.columns
data = movie.values
print(columns)
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
                 # Itt ha nem írok printet, akkor az utolsó, alsó típust írja ki.
                #Kikommentelhetem, amelyiket akarom és akkor csak a fölöttiek futnak le.

print(type(index))     
print(type(columns))
print(type(data))
'''Interestingly, both the types for both the index and the columns appear to be
closely related. The built-in issubclass method checks whether RangeIndex is
indeed a subclass of Index: '''
issubclass(pd.RangeIndex, pd.Index)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.base.Index'>
# <class 'numpy.ndarray'>
# True

# %%
'''Notice how the values DataFrame attribute returned a NumPy n-dimensional array, or
ndarray. Most of pandas relies heavily on the ndarray. Beneath the index, columns, and
data are NumPy ndarrays. They could be considered the base object for pandas that many
other objects are built upon. To see this, we can look at the values of the index and
columns:'''
print(index.values , "ezek az index értékei")

print(columns.values, " ezek meg az oszlopok nevei")
# Out:
# ['Avatar' "Pirates of the Caribbean: At World's End" 'Spectre' ...
#  'A Plague So Pleasant' 'Shanghai Calling' 'My Date with Drew'] ezek az index értékei
# ['color' 'director_name' 'num_critic_for_reviews' 'duration'
#  'director_facebook_likes' 'actor_3_facebook_likes' 'actor_2_name'
#  'actor_1_facebook_likes' 'gross' 'genres' 'actor_1_name'
#  'num_voted_users' 'cast_total_facebook_likes' 'actor_3_name'
#  'facenumber_in_poster' 'plot_keywords' 'movie_imdb_link'
#  'num_user_for_reviews' 'language' 'country' 'content_rating' 'budget'
#  'title_year' 'actor_2_facebook_likes' 'imdb_score' 'aspect_ratio'
#  'movie_facebook_likes']  ezek meg az oszlopok nevei

# %%
import matplotlib.pyplot as plt
movie.plot(kind="line")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[2,5,4])
plt.show()

# %%
movie=movie.dropna()
import matplotlib.pyplot as plt

plt.plot(movie.title_year, movie.gross)
plt.show()

# %%
plt.scatter(movie.title_year, movie.gross)
plt.show()

# %%
plt.hist(movie.title_year, bins=15)
plt.ylabel("Number of Movies")
plt.xlabel("Year of Movies shown")
plt.title("Filmek száma évek szerint: Historgram")
plt.show()

# %%
# read in the titanic data set
import pandas as pd
Titanic = pd.read_excel('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.xls')
print(Titanic.head())
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
print(movie.dtypes)
#Use the get_dtype_counts method to return the counts of each data type:
movie.get_dtype_counts()
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# ...

# %%
'''# One of the most useful methods for the object data type 
Series is value_counts, which counts all the occurrences of each unique value:'''
movie['director_name'].value_counts()
# Out:
# Steven Spielberg       25
# Woody Allen            19
# Clint Eastwood         19
# Martin Scorsese        16
# Ridley Scott           16
# Renny Harlin           15
# Steven Soderbergh      15
# Spike Lee              15
# Tim Burton             14
# Robert Zemeckis        13
# Ron Howard             13
# Robert Rodriguez       13
# Oliver Stone           13
# Barry Levinson         13
# Tony Scott             12
# Michael Bay            12
# Joel Schumacher        12
# Chris Columbus         11
# Shawn Levy             11
# Rob Reiner             11
# Richard Linklater      11
# Wes Craven             10
# Brian De Palma         10
# John Carpenter         10
# John McTiernan         10
# Kevin Smith            10
# Paul W.S. Anderson     10
# David Fincher          10
# Sam Raimi              10
# Dennis Dugan            9
#                        ..
# Michael D. Sellers      1
# Marcos Siega            1
# Stuart Beattie          1
# Philip G. Atwell        1
# ...

# %%
'''Counting the number of elements in the Series may be done with the size or
shape parameter or the len function:'''
director=movie['director_name']
director.to_frame()
print(director.size, "director size")
print(director.shape, "d shape")
print(len(director), "d hossza - sorok száma")
# number of non-missing values:
print (director.count(),   "nem null értékek száma") # fent a grafikonoknál kiszűrtük 
#a nullokat tartalmazó sorokat a dropna paranccsal
# Out:
# 3655 director size
# (3655,) d shape
# 3655 d hossza - sorok száma
# 3655 nem null értékek száma

# %%
#Basic summary statistics may be yielded with the min, max, mean, median, std,and sum methods:
movie.actor_1_facebook_likes.min()
movie.actor_1_facebook_likes.max() 
movie.actor_1_facebook_likes.mean()
movie.actor_1_facebook_likes.median()
movie.actor_1_facebook_likes.std()
movie.actor_1_facebook_likes.sum()
movie.actor_1_facebook_likes.quantile(.50)  #medián 50. precentilis
movie['actor_1_facebook_likes'].sum()
# Out:
# 28046752.0

# %%
movie.actor_1_facebook_likes.describe()     #Numerikus oszlopra
# Out:
# count      3655.000000
# mean       7673.529959
# std       15610.311700
# min           0.000000
# 25%         742.000000
# 50%        1000.000000
# 75%       12000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
director.describe()            # szöveg típusúra
# Out:
# count                 3655
# unique                1659
# top       Steven Spielberg
# freq                    25
# Name: director_name, dtype: object

# %%
# It is possible to replace all missing values within a Series with the fillna method:
movie.actor_1_facebook_likes.fillna(0)
#To remove the Series elements with missing values, use dropna:
movie.actor_1_facebook_likes.dropna().head()
# Out:
# movie_title
# Avatar                                       1000.0
# Pirates of the Caribbean: At World's End    40000.0
# Spectre                                     11000.0
# The Dark Knight Rises                       27000.0
# John Carter                                   640.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# Könyv 34. oldal
'''
The value_counts method is one of the most informative Series methods and heavily used
during exploratory analysis, especially with categorical columns. It defaults to returning the
counts, but by setting the normalize parameter to True, the relative frequencies are
returned instead, which provides another view of the distribution:
'''
director.value_counts(normalize=True).head()
# Out:
# Steven Spielberg    0.006840
# Woody Allen         0.005198
# Clint Eastwood      0.005198
# Martin Scorsese     0.004378
# Ridley Scott        0.004378
# Name: director_name, dtype: float64

# %%
print (movie.title_year.value_counts().head())     # Method chaining a counts és a head methoddal.
print('.........................')
#movie.title_year.value_counts()
# Out:
# 2002.0    185
# 2006.0    184
# 2008.0    180
# 2005.0    177
# 2009.0    176
# Name: title_year, dtype: int64
# .........................

# %%
director.hasnans     # False mert a grafikonrajzoláshoz eldobtuk az összes sort, amiben null volt a dropna paranccsal.
# Out:
# False

# %%
movie[director=='James Cameron']
# Out:
#                             color  director_name  num_critic_for_reviews  \
# movie_title
# Avatar                      Color  James Cameron                   723.0
# Titanic                     Color  James Cameron                   315.0
# Terminator 2: Judgment Day  Color  James Cameron                   210.0
# True Lies                   Color  James Cameron                    94.0
# The Abyss                   Color  James Cameron                    82.0
# Aliens                      Color  James Cameron                   250.0
# The Terminator              Color  James Cameron                   204.0
#
#                             duration  director_facebook_likes  \
# movie_title
# Avatar                         178.0                      0.0
# Titanic                        194.0                      0.0
# Terminator 2: Judgment Day     153.0                      0.0
# True Lies                      141.0                      0.0
# ...

# %%
movie.loc['Aliens'].head()
# Out:
# color                              Color
# director_name              James Cameron
# num_critic_for_reviews               250
# duration                             154
# director_facebook_likes                0
# Name: Aliens, dtype: object

# %%
'''
Chaining Series methods together
In Python, every variable is an object, and all objects have attributes and methods that refer
to or return more objects. The sequential invocation of methods using the dot notation is
referred to as method chaining. Pandas is a library that lends itself well to method
chaining, as many Series and DataFrame methods return more Series and DataFrames,
upon which more methods can be called.
Since Python does not normally allow a
single expression to be written on multiple lines, you need to use the backslash line
continuation character. Alternatively, you may wrap the whole expression in parentheses.
'''
# Out:
# '\nChaining Series methods together\nIn Python, every variable is an object, and all objects have attributes and methods that refer\nto or return more objects. The sequential invocation of methods using the dot notation is\nreferred to as method chaining. Pandas is a library that lends itself well to method\nchaining, as many Series and DataFrame methods return more Series and DataFrames,\nupon which more methods can be called.\nSince Python does not normally allow a\nsingle expression to be written on multiple lines, you need to use the backslash line\ncontinuation character. Alternatively, you may wrap the whole expression in parentheses.\n'

# %%
# Renaming row and column names  Könyv 43. oldal
# The rename DataFrame method accepts dictionaries that map the old value to the
# new value. Let's create one for the rows and another for the columns:
idx_rename = {'Avatar':'Ratava', 'Spectre': 'Ertceps'}
col_rename = {'director_name':'Director Name',
'num_critic_for_reviews': 'Critical Reviews','duration': 'Film hossza', 'director_facebook_likes':'Dir_FB_likes'}
movie = movie.rename(index=idx_rename,
columns=col_rename)

# %%
movie.head()
# Out:
#                                           color      Director Name  \
# movie_title
# Ratava                                    Color      James Cameron
# Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# Ertceps                                   Color         Sam Mendes
# The Dark Knight Rises                     Color  Christopher Nolan
# John Carter                               Color     Andrew Stanton
#
#                                           Critical Reviews  Film hossza  \
# movie_title
# Ratava                                               723.0        178.0
# Pirates of the Caribbean: At World's End             302.0        169.0
# Ertceps                                              602.0        148.0
# The Dark Knight Rises                                813.0        164.0
# John Carter                                          462.0        132.0
#
#                                           Dir_FB_likes  \
# movie_title
# ...

# %%
# Creating and deleting columns
movie['actor_director_facebook_likes'] = movie['actor_1_facebook_likes'] + movie['Dir_FB_likes']
movie['is_cast_likes_more'] = (movie['cast_total_facebook_likes'] >= movie['actor_director_facebook_likes'])
movie.head()
# Out:
#                                           color      Director Name  \
# movie_title
# Ratava                                    Color      James Cameron
# Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# Ertceps                                   Color         Sam Mendes
# The Dark Knight Rises                     Color  Christopher Nolan
# John Carter                               Color     Andrew Stanton
#
#                                           Critical Reviews  Film hossza  \
# movie_title
# Ratava                                               723.0        178.0
# Pirates of the Caribbean: At World's End             302.0        169.0
# Ertceps                                              602.0        148.0
# The Dark Knight Rises                                813.0        164.0
# John Carter                                          462.0        132.0
#
#                                           Dir_FB_likes  \
# movie_title
# ...

# %%
# is_cast_likes_more is now a column of boolean values. We can check
# whether all the values of this column are True with the all Series method:
movie['is_cast_likes_more'].all()
# Out:
# False

# %%
movie = movie.drop('is_cast_likes_more',axis='columns')
# vagy  del movie['actor_director_facebook_likes']

# %%
'''
It is possible to insert a new column into a specific place in a DataFrame besides the end
with the insert method. The insert method takes the integer position of the new column
as its first argument, the name of the new column as its second, and the values as its third.
You will need to use the get_loc Index method to find the integer location of the column
name. The profit of each movie may be calculated by subtracting budget
from gross and inserting it directly after gross with the following:
'''
profit_index = movie.columns.get_loc('gross') + 1
print(profit_index)
movie.insert(loc=profit_index, column='profit', value=movie['gross'] - movie['budget'])
movie.head()
# Out:
# 9
#                                           color      Director Name  \
# movie_title
# Ratava                                    Color      James Cameron
# Pirates of the Caribbean: At World's End  Color     Gore Verbinski
# Ertceps                                   Color         Sam Mendes
# The Dark Knight Rises                     Color  Christopher Nolan
# John Carter                               Color     Andrew Stanton
#
#                                           Critical Reviews  Film hossza  \
# movie_title
# Ratava                                               723.0        178.0
# Pirates of the Caribbean: At World's End             302.0        169.0
# Ertceps                                              602.0        148.0
# The Dark Knight Rises                                813.0        164.0
# John Carter                                          462.0        132.0
#
#                                           Dir_FB_likes  \
# movie_title
# ...
